# %%
import shelve

# Replace 'your_shelve_file' with the actual name of your shelve file (without the .dat extension)
with shelve.open('/home/law/Storage/03_Work/MyProjects/python-whatsapp-bot/threads_db') as db:
    for key in db:
        print(f'Key: {key}')
        print(f'Value: {db[key]}')
        print('---')
# Out:
# Key: 56942796937
# Value: thread_jb244FcgA0shNyHaR6hwzyGK
# ---

# %%
import shelve

with shelve.open('/home/law/Storage/03_Work/MyProjects/python-whatsapp-bot/threads_db') as threads_shelf:
    print(threads_shelf.get('56942796937', None))
# Out:
# thread_jb244FcgA0shNyHaR6hwzyGK
